# %% [markdown]
# <a href="https://colab.research.google.com/github/D-DePablos/Hack-Oxford/blob/master/Stage_4.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # Stage 4 : Image processing
#
# If we want to get more into what we use Python for daily at MSSL, creating, editing and playing with images will be an important use-case!

# %% [markdown]
# ## Downloading and displaying an Image
#
# The first step to working with images in Python is to get an image ready. We will be using the MSSL logo as an example image, but any image URL will work in this section.

# %%
import urllib.request


url = 'https://www.ukspacefacilities.stfc.ac.uk/Gallery/MSSL_Logo_360x222.jpg'

urllib.request.urlretrieve(url, "image.jpg")
# Out:
# ('image.jpg', <http.client.HTTPMessage at 0x7fc6d63a4080>)

# %% [markdown]
# Once we have downloaded the image locally (saved as image.jpg), we can have a look at what we have. Check that everything looks fine!

# %%
image = plt.imread('image.jpg')

plt.imshow(image)

plt.show()



import cv2
im = cv2.imread("image.jpg")
print(type(im))
# Out:
# <class 'numpy.ndarray'>

# %% [markdown]
# ##The true nature of Images
#
# As you may have expected (perhaps not?), images are no more than arrays of numbers that give information about position, colour and saturation of each of the pixels, for each of Red, Green and Blue.
#
# This is why the image we just plotted has numbered axes!
#
#
# So this is what the MSSL logo looks like to Python...

# %%
# print(image)

image.shape

im[:,:,1] = 1

# %% [markdown]
# This is very powerful, as it allows us to use images as if they were numerical arrays!

# %%
import numpy as np

# im = np.zeros((20, 20))
# im[5:-5, 5:-5] = 1

plt.imshow(im)

# %%
fancyword = 'Hello World!'

# %%
fancyword

# %% [markdown]
# Strings can be joined together simply by using +

# %%
'Hello' + " " + 'World'

# %% [markdown]
# ## Conditionals (IF you want to, or ELSE you don't)
#
# Conditionals are used to make certain parts of run if a certain condition is met. Trying change the value of A and seeing what happens

# %%
A = "Apple"
if A == "Apple":
    print("It's a Apple")
else:
    print("It's an Orange")

# %% [markdown]
# ## Loop de Loops
#
# Loops are used to repeat a code while a condition has/hasn't been met. Below are an examples of a "while" and "for" Loop

# %%
i = 10
while i > 0:
    i = i - 1 
    print("What is it?")
    
print("It's a red and blue striped golfing umbrella")

# %% [markdown]
# ## Lists
#
# Unsurprisingly, a list is a list of things.

# %%
a = [1,5,1,3,8]

# %% [markdown]
# To access a different thing in the list, you index the list like a[0]. Note: python starts counting at 0

# %%
a[0]

# %%
a[3]

# %% [markdown]
# ## List slicing
#
# Slicing is used to select a certain section of a list

# %%
ListyList = [1977,1978,1981,1984,2005,2019]

# %%
ListyList[:2]

# %%
ListyList[1:]

# %%
ListyList[1:3]

# %% [markdown]
# ## Dictionaries
#
# Dictionaries are another type of data structure (like a list). They essentially allow you to link a "key" with a "value". For example, imagine you wanted to keep track of how many apples (value) some people (key) had.

# %%
AppleDict = {"Alice":5,"Bob":12,"Clive":16}

# %% [markdown]
# You can then find out how many apples a person has by using the name as the index.

# %%
AppleDict["Bob"]
